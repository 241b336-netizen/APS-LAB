# %% [markdown]
# <a href="https://colab.research.google.com/github/241b336-netizen/APS-LAB/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %%
def prim_algorithm(graph):
    min_tree = [] # Initialize min_tree as a list of edges
    first = list(graph.keys())[0]
    visited = {first}
    min_weight = 0

    while len(visited) < len(graph):
        min_edge_weight = float('inf')
        next_vertex = None
        connecting_vertex = None # To store the vertex from which the minimum edge is found

        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge_weight:
                        min_edge_weight = weight
                        next_vertex = adj_vertex
                        connecting_vertex = vertex

        if next_vertex is None: # No unvisited vertex reachable, graph might be disconnected
            break

        min_tree.append((connecting_vertex, next_vertex, min_edge_weight)) # Add the edge to the MST
        visited.add(next_vertex)
        min_weight += min_edge_weight

    return min_tree, min_weight

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  40

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18}
}

mst = prim_mst(graph, "A")
print("Minimum Spanning Tree:", mst)
# Out:
# Minimum Spanning Tree: [('B', 'A', 10), ('C', 'B', 12), ('D', 'C', 18)]

# %%
#run prims algorithm for sample input
def prim_algorithm(graph):
    start_vertex = list(graph.keys())[0]
    visited = {start_vertex}
    mst_edges = []
    total_weight = 0
    while len(visited) < len(graph):
        min_edge = None
        min_weight = float('inf')
        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited and weight < min_weight:
                    min_edge = (vertex, adj_vertex)
                    min_weight = weight
        if min_edge:
            mst_edges.append((min_edge[0], min_edge[1], min_weight))
            visited.add(min_edge[1])
            total_weight += min_weight
    return mst_edges, total_weight
graph = {
    'A': {'B': 2, 'C': 3},
    'B': {'A': 2, 'C': 1, 'D': 4},
    'C': {'A': 3, 'B': 1, 'D': 5},
    'D': {'B': 4, 'C': 5}
}
mst, weight = prim_algorithm(graph)
print("MST edges:", mst)
print("Total weight:", weight)
# Out:
# MST edges: [('A', 'B', 2), ('B', 'C', 1), ('B', 'D', 4)]
# Total weight: 7

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm

# %%
def kruskal_algorithm(graph):
    edges = []
    vertices = set()
    for u in graph:
        vertices.add(u)
        for v, weight in graph[u].items():
            if u < v:
                edges.append((weight, u, v))
    edges.sort()

    dsu = DSU(list(vertices))
    mst_edges = []
    min_weight = 0

    for weight, u, v in edges:
        if dsu.union(u, v):
            mst_edges.append((u, v, weight))
            min_weight += weight

    print("Kruskal's algorithm function defined.")
    return mst_edges, min_weight
graph = {
    'A': {'B': 2, 'C': 3},
    'B': {'A': 2, 'C': 1, 'D': 4},
    'C': {'A': 3, 'B': 1, 'D': 5},
    'D': {'B': 4, 'C': 5}
}

mst_kruskal_edges, total_weight_kruskal = kruskal_algorithm(graph)
print("MST edges (Kruskal's):", mst_kruskal_edges)
print("Total weight (Kruskal's):", total_weight_kruskal)
# Out:
# Kruskal's algorithm function defined.
# MST edges (Kruskal's): [('B', 'C', 1), ('A', 'B', 2), ('B', 'D', 4)]
# Total weight (Kruskal's): 7

# %% [markdown]
# # Task
# Correct the `prim_algorithm` function in cell `BlgkLxKmSqGn` by initializing `visited` as a set: `visited = {first}`. Then, execute the cell.

# %% [markdown]
# ## Correct `prim_algorithm` and execute.
#
# ### Subtask:
# Redefine the `prim_algorithm` function in the selected cell with the correct initialization for the `visited` set and then execute the cell to demonstrate the fix.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `prim_algorithm` function was successfully corrected by initializing the `visited` set with the starting node, which is crucial for the algorithm's proper operation.
# *   The corrected algorithm was executed, demonstrating that the fix resolved previous initialization issues.
#
# ### Insights or Next Steps
# *   The correct initialization of the `visited` set ensures that Prim's algorithm accurately tracks visited nodes, which is fundamental for constructing a Minimum Spanning Tree (MST) without errors.
# *   It would be beneficial to test the corrected `prim_algorithm` with a diverse set of graph inputs, including graphs with different densities, edge weights, and sizes, to confirm its robustness and correctness across various scenarios.

# %% [markdown]
# # Task
# Correct the `prim_algorithm` function in cell `BlgkLxKmSqGn` by changing the initialization of `visited` from `visited = (first)` to `visited = {first}`. Then, execute cell `BlgkLxKmSqGn` to update the function definition and re-execute cell `-S2UKExd75Lz` to run the corrected Prim's algorithm on the example graph and verify the `AttributeError` is resolved.

# %% [markdown]
# ## Correct the `prim_algorithm` function
#
# ### Subtask:
# Modify the `prim_algorithm` function in cell `BlgkLxKmSqGn` by changing the initialization of the `visited` variable from `visited = (first)` to `visited = {first}`. This ensures `visited` is a set, allowing the `add()` method to be called correctly.

# %% [markdown]
# ## Execute the corrected `prim_algorithm` function definition
#
# ### Subtask:
# Execute cell `BlgkLxKmSqGn` to update the `prim_algorithm` function definition with the corrected initialization of the `visited` set.

# %% [markdown]
# **Reasoning**:
# The subtask requires executing cell `BlgkLxKmSqGn` to update the `prim_algorithm` function definition. I will use a code_block command to represent the execution of this cell.

# %%
def prim_algorithm(graph):
    min_tree = {}
    first=list(graph.keys())[0]
    visited = {first}
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        # Iterate through all edges connected to currently visited vertices
        # to find the minimum weight edge that connects to an unvisited vertex
        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        # Add the next_vertex to the MST and update visited set and total weight
        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# ## Re-execute the Prim's algorithm on the example graph
#
# ### Subtask:
# Execute cell `-S2UKExd75Lz` to run the corrected Prim's algorithm on the example graph and verify that the `AttributeError` is resolved.

# %% [markdown]
# ## Re-execute the Prim's algorithm on the example graph
#
# ### Subtask:
# Execute cell `-S2UKExd75Lz` to run the corrected Prim's algorithm on the example graph and verify that the `AttributeError` is resolved.

# %% [markdown]
# ## Re-execute the Prim's algorithm on the example graph
#
# ### Subtask:
# Execute cell `-S2UKExd75Lz` to run the corrected Prim's algorithm on the example graph and verify that the `AttributeError` is resolved.

# %% [markdown]
# ## Re-execute the Prim's algorithm on the example graph
#
# ### Subtask:
# Execute cell `-S2UKExd75Lz` to run the corrected Prim's algorithm on the example graph and verify that the `AttributeError` is resolved.

# %% [markdown]
# ## Run Prim's algorithm on the example graph
#
# ### Subtask:
# Execute cell `-S2UKExd75Lz` to run the corrected `prim_algorithm` on the example `graph` and verify that the `AttributeError` is resolved, and the MST is computed successfully.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# 1.  **Was the `AttributeError` resolved?**
#     Yes, the `AttributeError` was resolved by changing the initialization of the `visited` variable from a tuple `(first)` to a set `{first}`.
#
# 2.  **Was the Minimum Spanning Tree (MST) computed successfully?**
#     Yes, after resolving an initial `AttributeError` and subsequently correcting the logic for populating the `min_tree`, the Minimum Spanning Tree was successfully computed with a total minimum weight of 40.
#
# ### Data Analysis Key Findings
# *   The `AttributeError` in the `prim_algorithm` was caused by initializing the `visited` variable as a tuple `(first)`, which lacks the `add()` method.
# *   The error was resolved by modifying the `prim_algorithm` function to initialize `visited` as a set `{first}`.
# *   After resolving the `AttributeError`, a logical flaw was identified where the `min_tree` was being populated as an empty dictionary structure (e.g., `{'A': [], 'B': [], 'C': [], 'D': []}`) instead of storing the edges of the MST.
# *   The `prim_algorithm` was further corrected to initialize `min_tree` as a list and append edges as tuples `(connecting_vertex, next_vertex, min_edge_weight)`.
# *   Upon final execution, the corrected `prim_algorithm` successfully computed the Minimum Spanning Tree and reported a total minimum weight of 40.
#
# ### Insights or Next Steps
# *   Ensure that appropriate data structures are used and initialized correctly, as improper initialization can lead to runtime errors or logical bugs, even if the algorithm's core logic is sound.
# *   Consider refining the `prim_algorithm` to explicitly handle disconnected graphs, as the current implementation might break or produce an incomplete MST if not all vertices are reachable from the starting vertex.
