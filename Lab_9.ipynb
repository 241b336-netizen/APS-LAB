# %% [markdown]
# <a href="https://colab.research.google.com/github/241b336-netizen/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 4},
    'D': {'B': 10, 'C': 3, 'F': 11},
    'E': {'C': 4, 'F': 2},
    'F': {'D': 11, 'E': 2}
}





import heapq
def dijkstra(graph, start):
    queue = [(0, start, [start])]
    distances = {node: float('inf') for node in graph}
    paths = {node: [] for node in graph}
    distances[start] = 0
    while queue:
        current_distance, current_node, path = heapq.heappop(queue)
        if current_distance > distances[current_node]:
            continue
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                paths[neighbor] = path + [neighbor]
                heapq.heappush(queue, (distance, neighbor, path + [neighbor]))
    return distances, paths

source_nodes = ['A', 'C', 'E']
for source in source_nodes:
    distances, paths = dijkstra(graph, source)
    print("\nShortest paths from", source)
    for node in graph:
        if node == source:
            continue
        print(f"Path to {node}: {' -> '.join(paths[node])} | Distance = {distances[node]}")
# Out:
# Shortest paths from A
# Path to B: A -> B | Distance = 4
# Path to C: A -> C | Distance = 2
# Path to D: A -> C -> D | Distance = 5
# Path to E: A -> C -> E | Distance = 6
# Path to F: A -> C -> E -> F | Distance = 8
#
# Shortest paths from C
# Path to A: C -> A | Distance = 2
# Path to B: C -> B | Distance = 5
# Path to D: C -> D | Distance = 3
# Path to E: C -> E | Distance = 4
# Path to F: C -> E -> F | Distance = 6
#
# Shortest paths from E
# Path to A: E -> C -> A | Distance = 6
# Path to B: E -> C -> B | Distance = 9
# Path to C: E -> C | Distance = 4
# Path to D: E -> C -> D | Distance = 7
# Path to F: E -> F | Distance = 2

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph,start):
  distance = {}
  visited = []
  for node in graph:

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
graph={}
n=int(input("enter nodes"))

for i in range(n):
  node=input(f"enter name{i+1}:")
  graph[node]={}
e=int(input("enetr edges"))
print("enter edges in format: source_node destination_node weight ")
for i in range(e):
  u,v,m=input(f"edges{i+1}:").split()
  w=int(m)
  graph[u][v]=w
start=input("enter the starting")
result=dijkstra(graph,start)
print(start)
for node in result:
  print("distance from",start,"to",node,"=",result[node])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11391/831601553.py in <cell line: 0>()
#       1 graph={}
# ----> 2 n=int(input("enter nodes"))
#       3
#       4 for i in range(n):
#       5   node=input(f"enter name{i+1}:")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
